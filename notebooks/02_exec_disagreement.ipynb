# %% [markdown]
# # Phase 2 — Execution grading disagreement
#
# Pass rate under each comparison definition (strict through null_normalized). The spread between them is itself a finding: it quantifies how much of "execution accuracy" is a definitional choice rather than a fact about the model. Then perturb the database and measure the spurious pass rate.

# %%
import sys
from pathlib import Path

# Notebooks live one level down, so src/ needs to be on the path.
sys.path.insert(0, str(Path.cwd().parent / 'src'))

import pandas as pd
from schema import load_dev, schema_ddl, db_path
from sample import select_baseline
