# %% [markdown]
# # Phase 3 — Judge validation
#
# Confusion matrix against the 150 hand labels. Sensitivity, specificity, Cohen kappa reported alongside raw agreement, bootstrap CIs on all of it. Then Rogan-Gladen and the Bayesian posterior on the true pass rate.

# %%
import sys
from pathlib import Path

# Notebooks live one level down, so src/ needs to be on the path.
sys.path.insert(0, str(Path.cwd().parent / 'src'))

import pandas as pd
from schema import load_dev, schema_ddl, db_path
from sample import select_baseline
