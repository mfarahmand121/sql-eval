# %% [markdown]
# # Phase 1 — Open coding
#
# Read 100 traces by hand. Free-text notes only, no categories yet: writing the taxonomy in advance just confirms your priors. Cluster into 8-15 mutually exclusive failure modes afterwards, then re-label all 100 against the finalized taxonomy to get a self-agreement rate.
